# %% [markdown]
# ## Phase 2

# %%
#Importing necessary libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#Importing the dataset
df=pd.read_csv(r'D:\Files\Phase1_data.csv')
df
# Out:
#              STATE/UT  population_2001  population_2002  population_2003  \
# 0      ANDHRA PRADESH         75728400         73094239         70460078
# 1   ARUNACHAL PRADESH          1098328          1126756          1155184
# 2               ASSAM         26638600         27091667         27544734
# 3               BIHAR         82879910         84972382         87064854
# 4        CHHATTISGARH         20834530         21305096         21775662
# 5                 GOA          1348900          1359782          1370664
# 6             GUJARAT         50597200         51575842         52554484
# 7             HARYANA         21083900         21550818         22017736
# 8    HIMACHAL PRADESH          6077453          6155358          6233263
# 9     JAMMU & KASHMIR         10070300         10318162         10566024
# 10          JHARKHAND         26946070         27550276         28154482
# 11          KARNATAKA         52734986         53574557         54414128
# ...

# %% [markdown]
# This data frame contains information related to **India Crime**. It contains **34 rows and 40 columns**.
#
# The data frame contains both **numeric data and categorical data.**

# %% [markdown]
# ## 2.1

# %% [markdown]
# **Analysis of Literacy Rate vs Total Crimes for the year 2001**

# %%
#using scatter plot

sb.scatterplot(x='literacy_2001',y='TOTAL IPC CRIMES',data=df)
plt.title('Literacy Rate vs Total Crimes for year 2001')
plt.xlabel('Literacy Rate')
plt.ylabel('Total Crimes')
plt.show()

# %%
#using line plot
sb.lineplot(x='literacy_2001',y='TOTAL IPC CRIMES',data=df)
plt.title('Literacy Rate vs Total Crimes for year 2001')
plt.xlabel('Literacy Rate')
plt.ylabel('Total Crimes')
plt.show()

# %% [markdown]
# The 2001 data shows a noisy pattern without a clear trend.

# %% [markdown]
# **Analysis of Literacy Rate vs Total Crimes for the year 2012**

# %%
#using scatter plot

sb.scatterplot(x='literacy_2012',y='TOTAL IPC CRIMES',data=df)
plt.title('Literacy Rate vs Total Crimes for year 2012')
plt.xlabel('Literacy Rate')
plt.ylabel('Total Crimes')
plt.show()

# %%
#using line plot
sb.lineplot(x='literacy_2012',y='TOTAL IPC CRIMES',data=df)
plt.title('Literacy Rate vs Total Crimes for year 2012')
plt.xlabel('Literacy Rate')
plt.ylabel('Total Crimes')
plt.show()

# %% [markdown]
# We can observe that there is non-uniform decline in Total Crimes as the Literacy Rate increases.

# %% [markdown]
# ## 2.2

# %% [markdown]
# **Analysis of the type of crime vs each state vs Literacy rate for year 2001**

# %%
#using scatter plot
plt.figure(figsize=(10,8))
sb.scatterplot(x='STATE/UT',y='literacy_2001',hue='TYPE OF CRIME',data=df)
plt.title('Type of crime vs each state vs Literacy rate for year 2001')
plt.xlabel('State')
plt.ylabel('Literacy Rate')
plt.xticks(rotation=90)
plt.show()

# %%
#using line plot
plt.figure(figsize=(10,8))
sb.lineplot(x='STATE/UT',y='literacy_2001',hue='TYPE OF CRIME',data=df)
plt.title('Type of crime vs each state vs Literacy rate for year 2001')
plt.xlabel('State')
plt.ylabel('Literacy Rate')
plt.xticks(rotation=90)
plt.show()

# %%
#using barplot
plt.figure(figsize=(12,10))
sb.barplot(x='STATE/UT',y='literacy_2001',hue='TYPE OF CRIME',data=df)
plt.title('Type of crime vs each state vs Literacy rate for year 2001')
plt.xlabel('State')
plt.ylabel('Literacy Rate')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# We can observe that **'THEFT'** is the most frequently occurring type of crime.
#
# **'RIOTS'** is the least frequently occurring type of crime.
#
# The top three states are **Kerala**, where the type of crime is **'HURT/GREVIOUS HURT'**, followed by **Lakshadweep** with **'RIOTS'** and finally, **Mizoram** with **'THEFT'**.

# %% [markdown]
# **Analysis of the type of crime vs each state vs Literacy rate for year 2012**

# %%
#using scatter plot
plt.figure(figsize=(10,8))
sb.scatterplot(x='STATE/UT',y='literacy_2012',hue='TYPE OF CRIME',data=df)
plt.title('Type of crime vs each state vs Literacy rate for year 2012')
plt.xlabel('State')
plt.ylabel('Literacy Rate')
plt.xticks(rotation=90)
plt.show()

# %%
#using line plot
plt.figure(figsize=(10,8))
sb.lineplot(x='STATE/UT',y='literacy_2012',hue='TYPE OF CRIME',data=df)
plt.title('Type of crime vs each state vs Literacy rate for year 2012')
plt.xlabel('State')
plt.ylabel('Literacy Rate')
plt.xticks(rotation=90)
plt.show()

# %%
#using barplot
plt.figure(figsize=(12,10))
sb.barplot(x='STATE/UT',y='literacy_2012',hue='TYPE OF CRIME',data=df)
plt.title('Type of crime vs each state vs Literacy rate for year 2012')
plt.xlabel('State')
plt.ylabel('Literacy Rate')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# We can observe that **'THEFT'** is still the most frequently occurring type of crime.
#
# **'RIOTS'** is the least frequently occurring type of crime.
#
# The top three states remain the same: **Kerala**, where the type of crime is **'HURT/GREVIOUS HURT'**, followed by **Lakshadweep** with **'RIOTS'** and finally, **Mizoram** with **'THEFT'**.

# %% [markdown]
# ## 2.3

# %% [markdown]
# **Analysis of year-on-year total crime rate for year 2001 and 2002**

# %%
#using scatter plot
plt.figure(figsize=(10,8))
sb.scatterplot(x='CRIME RATE 2001',y='CRIME RATE 2002',data=df)
plt.title('CRIME RATE 2001 vs CRIME RATE 2002')
plt.xlabel('CRIME RATE 2001')
plt.ylabel('CRIME RATE 2002')
plt.show()

# %%
#using line plot
plt.figure(figsize=(10,8))
sb.lineplot(x='CRIME RATE 2001',y='CRIME RATE 2002',data=df)
plt.title('CRIME RATE 2001 vs CRIME RATE 2002')
plt.xlabel('CRIME RATE 2001')
plt.ylabel('CRIME RATE 2002')
plt.show()

# %%
#using lmplot
plt.figure(figsize=(10,8))
sb.lmplot(x='CRIME RATE 2001',y='CRIME RATE 2002',data=df)
plt.title('CRIME RATE 2001 vs CRIME RATE 2002')
plt.xlabel('CRIME RATE 2001')
plt.ylabel('CRIME RATE 2002')
plt.show()

# %% [markdown]
# We can observe that **crime rate** is **significantly increased** from year **2001 to 2002**.

# %% [markdown]
# **Analysis of year-on-year total crime rate for year 2002 and 2003**

# %%
#using scatter plot
plt.figure(figsize=(10,8))
sb.scatterplot(x='CRIME RATE 2002',y='CRIME RATE 2003',data=df)
plt.title('CRIME RATE 2002 vs CRIME RATE 2003')
plt.xlabel('CRIME RATE 2002')
plt.ylabel('CRIME RATE 2003')
plt.show()

# %%
#using line plot
plt.figure(figsize=(10,8))
sb.lineplot(x='CRIME RATE 2002',y='CRIME RATE 2003',data=df)
plt.title('CRIME RATE 2002 vs CRIME RATE 2003')
plt.xlabel('CRIME RATE 2002')
plt.ylabel('CRIME RATE 2003')
plt.show()

# %%
#using lm plot
plt.figure(figsize=(10,8))
sb.lmplot(x='CRIME RATE 2002',y='CRIME RATE 2003',data=df)
plt.title('CRIME RATE 2002 vs CRIME RATE 2003')
plt.xlabel('CRIME RATE 2002')
plt.ylabel('CRIME RATE 2003')
plt.show()

# %% [markdown]
# We can observe that **crime rate** is **significantly increased** from year **2002 to 2003**.

# %% [markdown]
# **Analysis of year-on-year total crime rate for year 2003 and 2004**

# %%
#using scatter plot
plt.figure(figsize=(10,8))
sb.scatterplot(x='CRIME RATE 2003',y='CRIME RATE 2004',data=df)
plt.title('CRIME RATE 2003 vs CRIME RATE 2004')
plt.xlabel('CRIME RATE 2003')
plt.ylabel('CRIME RATE 2004')
plt.show()

# %%
#using line plot
plt.figure(figsize=(10,8))
sb.lineplot(x='CRIME RATE 2003',y='CRIME RATE 2004',data=df)
plt.title('CRIME RATE 2003 vs CRIME RATE 2004')
plt.xlabel('CRIME RATE 2003')
plt.ylabel('CRIME RATE 2004')
plt.show()

# %%
#using lm plot
plt.figure(figsize=(10,8))
sb.lmplot(x='CRIME RATE 2003',y='CRIME RATE 2004',data=df)
plt.title('CRIME RATE 2003 vs CRIME RATE 2004')
plt.xlabel('CRIME RATE 2003')
plt.ylabel('CRIME RATE 2004')
plt.show()

# %% [markdown]
# We can observe that **crime rate** is **significantly increased** from year **2003 to 2004**.

# %% [markdown]
# **Analysis of year-on-year total crime rate for year 2004 and 2005**

# %%
#using scatter plot
plt.figure(figsize=(10,8))
sb.scatterplot(x='CRIME RATE 2004',y='CRIME RATE 2005',data=df)
plt.title('CRIME RATE 2004 vs CRIME RATE 2005')
plt.xlabel('CRIME RATE 2004')
plt.ylabel('CRIME RATE 2005')
plt.show()

# %%
#using line plot
plt.figure(figsize=(10,8))
sb.lineplot(x='CRIME RATE 2004',y='CRIME RATE 2005',data=df)
plt.title('CRIME RATE 2004 vs CRIME RATE 2005')
plt.xlabel('CRIME RATE 2004')
plt.ylabel('CRIME RATE 2005')
plt.show()

# %%
#using lm plot
plt.figure(figsize=(10,8))
sb.lmplot(x='CRIME RATE 2004',y='CRIME RATE 2005',data=df)
plt.title('CRIME RATE 2004 vs CRIME RATE 2005')
plt.xlabel('CRIME RATE 2004')
plt.ylabel('CRIME RATE 2005')
plt.show()

# %% [markdown]
# We can observe that **crime rate** is **significantly increased** from year **2004 to 2005**.

# %% [markdown]
# **Analysis of year-on-year total crime rate for year 2005 and 2006**

# %%
#using scatter plot
plt.figure(figsize=(10,8))
sb.scatterplot(x='CRIME RATE 2005',y='CRIME RATE 2006',data=df)
plt.title('CRIME RATE 2005 vs CRIME RATE 2006')
plt.xlabel('CRIME RATE 2005')
plt.ylabel('CRIME RATE 2006')
plt.show()

# %%
#using line plot
plt.figure(figsize=(10,8))
sb.lineplot(x='CRIME RATE 2005',y='CRIME RATE 2006',data=df)
plt.title('CRIME RATE 2005 vs CRIME RATE 2006')
plt.xlabel('CRIME RATE 2005')
plt.ylabel('CRIME RATE 2006')
plt.show()

# %%
#using lm plot
plt.figure(figsize=(10,8))
sb.lmplot(x='CRIME RATE 2005',y='CRIME RATE 2006',data=df)
plt.title('CRIME RATE 2005 vs CRIME RATE 2006')
plt.xlabel('CRIME RATE 2005')
plt.ylabel('CRIME RATE 2006')
plt.show()

# %% [markdown]
# We can observe that **crime rate** is **significantly increased** from year **2005 to 2006**.

# %% [markdown]
# **Analysis of year-on-year total crime rate for year 2006 and 2007**

# %%
#using scatter plot
plt.figure(figsize=(10,8))
sb.scatterplot(x='CRIME RATE 2006',y='CRIME RATE 2007',data=df)
plt.title('CRIME RATE 2006 vs CRIME RATE 2007')
plt.xlabel('CRIME RATE 2006')
plt.ylabel('CRIME RATE 2007')
plt.show()

# %%
#using line plot
plt.figure(figsize=(10,8))
sb.lineplot(x='CRIME RATE 2006',y='CRIME RATE 2007',data=df)
plt.title('CRIME RATE 2006 vs CRIME RATE 2007')
plt.xlabel('CRIME RATE 2006')
plt.ylabel('CRIME RATE 2007')
plt.show()

# %%
#using lm plot
plt.figure(figsize=(10,8))
sb.lmplot(x='CRIME RATE 2006',y='CRIME RATE 2007',data=df)
plt.title('CRIME RATE 2006 vs CRIME RATE 2007')
plt.xlabel('CRIME RATE 2006')
plt.ylabel('CRIME RATE 2007')
plt.show()

# %% [markdown]
# We can observe that **crime rate** is **significantly increased** from year **2006 to 2007**.

# %% [markdown]
# **Analysis of year-on-year total crime rate for year 2007 and 2008**

# %%
#using scatter plot
plt.figure(figsize=(10,8))
sb.scatterplot(x='CRIME RATE 2007',y='CRIME RATE 2008',data=df)
plt.title('CRIME RATE 2007 vs CRIME RATE 2008')
plt.xlabel('CRIME RATE 2007')
plt.ylabel('CRIME RATE 2008')
plt.show()

# %%
#using line plot
plt.figure(figsize=(10,8))
sb.lineplot(x='CRIME RATE 2007',y='CRIME RATE 2008',data=df)
plt.title('CRIME RATE 2007 vs CRIME RATE 2008')
plt.xlabel('CRIME RATE 2007')
plt.ylabel('CRIME RATE 2008')
plt.show()

# %%
#using lm plot
plt.figure(figsize=(10,8))
sb.lmplot(x='CRIME RATE 2007',y='CRIME RATE 2008',data=df)
plt.title('CRIME RATE 2007 vs CRIME RATE 2008')
plt.xlabel('CRIME RATE 2007')
plt.ylabel('CRIME RATE 2008')
plt.show()

# %% [markdown]
# We can observe that **crime rate** is **significantly increased** from year **2007 to 2008**.

# %% [markdown]
# **Analysis of year-on-year total crime rate for year 2008 and 2009**

# %%
#using scatter plot
plt.figure(figsize=(10,8))
sb.scatterplot(x='CRIME RATE 2008',y='CRIME RATE 2009',data=df)
plt.title('CRIME RATE 2008 vs CRIME RATE 2009')
plt.xlabel('CRIME RATE 2008')
plt.ylabel('CRIME RATE 2009')
plt.show()

# %%
#using line plot
plt.figure(figsize=(10,8))
sb.lineplot(x='CRIME RATE 2008',y='CRIME RATE 2009',data=df)
plt.title('CRIME RATE 2008 vs CRIME RATE 2009')
plt.xlabel('CRIME RATE 2008')
plt.ylabel('CRIME RATE 2009')
plt.show()

# %%
#using lm plot
plt.figure(figsize=(10,8))
sb.lmplot(x='CRIME RATE 2008',y='CRIME RATE 2009',data=df)
plt.title('CRIME RATE 2008 vs CRIME RATE 2009')
plt.xlabel('CRIME RATE 2008')
plt.ylabel('CRIME RATE 2009')
plt.show()

# %% [markdown]
# We can observe that **crime rate** is **significantly increased** from year **2008 to 2009**.

# %% [markdown]
# **Analysis of year-on-year total crime rate for year 2009 and 2010**

# %%
#using scatter plot
plt.figure(figsize=(10,8))
sb.scatterplot(x='CRIME RATE 2009',y='CRIME RATE 2010',data=df)
plt.title('CRIME RATE 2009 vs CRIME RATE 2010')
plt.xlabel('CRIME RATE 2009')
plt.ylabel('CRIME RATE 2010')
plt.show()

# %%
#using line plot
plt.figure(figsize=(10,8))
sb.lineplot(x='CRIME RATE 2009',y='CRIME RATE 2010',data=df)
plt.title('CRIME RATE 2009 vs CRIME RATE 2010')
plt.xlabel('CRIME RATE 2009')
plt.ylabel('CRIME RATE 2010')
plt.show()

# %%
#using lm plot
plt.figure(figsize=(10,8))
sb.lmplot(x='CRIME RATE 2009',y='CRIME RATE 2010',data=df)
plt.title('CRIME RATE 2009 vs CRIME RATE 2010')
plt.xlabel('CRIME RATE 2009')
plt.ylabel('CRIME RATE 2010')
plt.show()

# %% [markdown]
# We can observe that **crime rate** is **significantly increased** from year **2009 to 2010**.

# %% [markdown]
# **Analysis of year-on-year total crime rate for year 2010 and 2011**

# %%
#using scatter plot
plt.figure(figsize=(10,8))
sb.scatterplot(x='CRIME RATE 2010',y='CRIME RATE 2011',data=df)
plt.title('CRIME RATE 2010 vs CRIME RATE 2011')
plt.xlabel('CRIME RATE 2010')
plt.ylabel('CRIME RATE 2011')
plt.show()

# %%
#using line plot
plt.figure(figsize=(10,8))
sb.lineplot(x='CRIME RATE 2010',y='CRIME RATE 2011',data=df)
plt.title('CRIME RATE 2010 vs CRIME RATE 2011')
plt.xlabel('CRIME RATE 2010')
plt.ylabel('CRIME RATE 2011')
plt.show()

# %%
#using lm plot
plt.figure(figsize=(10,8))
sb.lmplot(x='CRIME RATE 2010',y='CRIME RATE 2011',data=df)
plt.title('CRIME RATE 2010 vs CRIME RATE 2011')
plt.xlabel('CRIME RATE 2010')
plt.ylabel('CRIME RATE 2011')
plt.show()

# %% [markdown]
# We can observe that **crime rate** is **significantly increased** from year **2010 to 2011**.

# %% [markdown]
# **Analysis of year-on-year total crime rate for year 2011 and 2012**

# %%
#using scatter plot
plt.figure(figsize=(10,8))
sb.scatterplot(x='CRIME RATE 2011',y='CRIME RATE 2012',data=df)
plt.title('CRIME RATE 2011 vs CRIME RATE 2012')
plt.xlabel('CRIME RATE 2011')
plt.ylabel('CRIME RATE 2012')
plt.show()

# %%
#using line plot
plt.figure(figsize=(10,8))
sb.lineplot(x='CRIME RATE 2011',y='CRIME RATE 2012',data=df)
plt.title('CRIME RATE 2011 vs CRIME RATE 2012')
plt.xlabel('CRIME RATE 2011')
plt.ylabel('CRIME RATE 2012')
plt.show()

# %%
#using lm plot
plt.figure(figsize=(10,8))
sb.lmplot(x='CRIME RATE 2011',y='CRIME RATE 2012',data=df)
plt.title('CRIME RATE 2011 vs CRIME RATE 2012')
plt.xlabel('CRIME RATE 2011')
plt.ylabel('CRIME RATE 2012')
plt.show()

# %% [markdown]
# We can observe that **crime rate** is **significantly increased** from year **2011 to 2012**.

# %% [markdown]
# We can conclude that from year **2001 to 2012**, **crime rate** has **significantly increased**.

# %% [markdown]
# ## 2.4

# %%
#using scatter plot
plt.figure(figsize=(10,8))
sb.scatterplot(x='Area (Km²)',y='TOTAL IPC CRIMES',data=df)
plt.title('Area vs TOTAL IPC CRIMES')
plt.xlabel('Area (Km²)')
plt.ylabel('TOTAL IPC CRIMES')
plt.show()

# %%
#using line plot
plt.figure(figsize=(10,8))
sb.lineplot(x='Area (Km²)',y='TOTAL IPC CRIMES',data=df)
plt.title('Area vs TOTAL IPC CRIMES')
plt.xlabel('Area (Km²)')
plt.ylabel('TOTAL IPC CRIMES')
plt.show()

# %%
#using lm plot
plt.figure(figsize=(10,8))
sb.lmplot(x='Area (Km²)',y='TOTAL IPC CRIMES',data=df)
plt.title('Area vs TOTAL IPC CRIMES')
plt.xlabel('Area (Km²)')
plt.ylabel('TOTAL IPC CRIMES')
plt.show()

# %% [markdown]
# From the above graphs, we can conclude that in larger states, more crimes are occurring.

# %% [markdown]
# ## 2.5

# %% [markdown]
# **Analysis of Population vs overall Crime for year 2012**

# %%
#using scatter plot
plt.figure(figsize=(10,8))
sb.scatterplot(x='population_2012',y='TOTAL IPC CRIMES',data=df)
plt.title('2012 Population vs TOTAL IPC CRIMES')
plt.xlabel('Population')
plt.ylabel('TOTAL IPC CRIMES')
plt.show()

# %%
#using line plot
plt.figure(figsize=(10,8))
sb.lineplot(x='population_2012',y='TOTAL IPC CRIMES',data=df)
plt.title('2012 Population vs TOTAL IPC CRIMES')
plt.xlabel('Population')
plt.ylabel('TOTAL IPC CRIMES')
plt.show()

# %%
#using lm plot
plt.figure(figsize=(10,8))
sb.lmplot(x='population_2012',y='TOTAL IPC CRIMES',data=df)
plt.title('2012 Population vs TOTAL IPC CRIMES')
plt.xlabel('Population')
plt.ylabel('TOTAL IPC CRIMES')
plt.show()

# %% [markdown]
# From the above graphs, we can observe that as the population increases, the occurrence of crimes also increases.

# %% [markdown]
# ## 2.62

# %%
#sorting data frame in descending order on basis of 'TOTAL IPC CRIMES'
df1=df[['STATE/UT','population_2001','population_2012','literacy_2001','literacy_2012','Area (Km²)','TOTAL IPC CRIMES','TYPE OF CRIME','CRIME RATE 2012']].sort_values(by='TOTAL IPC CRIMES',ascending=False)
df1
# Out:
#              STATE/UT  population_2001  population_2012  literacy_2001  \
# 13     MADHYA PRADESH         60385090         73818812          63.74
# 14        MAHARASHTRA         96752500        113935019          76.84
# 23         TAMIL NADU         62111390         73141714          73.45
# 0      ANDHRA PRADESH         75728400         46752638          60.47
# 25      UTTAR PRADESH        166053600        202934264          56.27
# 21          RAJASTHAN         56473300         69835783          60.41
# 11          KARNATAKA         52734986         61970275          66.06
# 12             KERALA         31839000         33542544          90.86
# 6             GUJARAT         50597200         61362270          69.14
# 3               BIHAR         82879910        105897102          47.00
# 27        WEST BENGAL         80221300         92460379          68.64
# 19             ODISHA         36707900         42471303          63.08
# ...

# %% [markdown]
# **Madhya Pradesh:**
#
# Population: 73,818,812
# Literacy Rate: 69.88%
# Most Frequent Crime: HURT/GREVIOUS HURT
# Total Crimes: 2,413,770
# Madhya Pradesh, with a population of 73,818,812 and a literacy rate of 69.88%, experiences HURT/GREVIOUS HURT as the most frequent crime, with a total of 2,413,770 reported cases.
#
# **Maharashtra:**
#
# Population: 113,935,019
# Literacy Rate: 82.89%
# Most Frequent Crime: THEFT
# Total Crimes: 2,273,436
# Maharashtra, with a population of 113,935,019 and a literacy rate of 82.89%, sees THEFT as the most frequent crime, with a total of 2,273,436 reported cases.
#
# **Tamil Nadu:**
#
# Population: 73,141,714
# Literacy Rate: 81.02%
# Most Frequent Crime: HURT/GREVIOUS HURT
# Total Crimes: 2,060,176
# Tamil Nadu, with a population of 73,141,714 and a literacy rate of 81.02%, reports HURT/GREVIOUS HURT as the most frequent crime, with a total of 2,060,176 cases.
#
# **Andhra Pradesh:**
#
# Population: 46,752,638
# Literacy Rate: 67.68%
# Most Frequent Crime: HURT/GREVIOUS HURT
# Total Crimes: 2,018,981
# Andhra Pradesh, with a population of 46,752,638 and a literacy rate of 67.68%, experiences HURT/GREVIOUS HURT as the most frequent crime, with a total of 2,018,981 reported cases.
#
# **Uttar Pradesh:**
#
# Population: 202,934,264
# Literacy Rate: 68.82%
# Most Frequent Crime: THEFT
# Total Crimes: 1,858,074
# Uttar Pradesh, with a population of 202,934,264 and a literacy rate of 68.82%, sees THEFT as the most frequent crime, with a total of 1,858,074 reported cases.
#
# **Rajasthan:**
#
# Population: 69,835,783
# Literacy Rate: 66.68%
# Most Frequent Crime: HURT/GREVIOUS HURT
# Total Crimes: 1,855,916
# Rajasthan, with a population of 69,835,783 and a literacy rate of 66.68%, experiences HURT/GREVIOUS HURT as the most frequent crime, with a total of 1,855,916 reported cases.
#
# **Karnataka:**
#
# Population: 61,970,275
# Literacy Rate: 76.29%
# Most Frequent Crime: HURT/GREVIOUS HURT
# Total Crimes: 1,481,063
# Karnataka, with a population of 61,970,275 and a literacy rate of 76.29%, reports HURT/GREVIOUS HURT as the most frequent crime, with a total of 1,481,063 cases.
#
# **Kerala:**
#
# Population: 33,542,544
# Literacy Rate: 94.31%
# Most Frequent Crime: HURT/GREVIOUS HURT
# Total Crimes: 1,437,459
# Kerala, with a population of 33,542,544 and a literacy rate of 94.31%, experiences HURT/GREVIOUS HURT as the most frequent crime, with a total of 1,437,459 reported cases.
#
# **Gujarat:**
#
# Population: 61,362,270
# Literacy Rate: 78.92%
# Most Frequent Crime: THEFT
# Total Crimes: 1,385,775
# Gujarat, with a population of 61,362,270 and a literacy rate of 78.92%, sees THEFT as the most frequent crime, with a total of 1,385,775 reported cases.
#
# **Bihar:**
#
# Population: 105,897,102
# Literacy Rate: 63.28%
# Most Frequent Crime: HURT/GREVIOUS HURT
# Total Crimes: 1,346,293
# Bihar, with a population of 105,897,102 and a literacy rate of 63.28%, experiences HURT/GREVIOUS HURT as the most frequent crime, with a total of 1,346,293 reported cases.
#
# **West Bengal:**
# Population: 92,460,379
# Literacy Rate: 77.02%
# Most Frequent Crime: THEFT
# Total Crimes: 1,119,304
# West Bengal, with a population of 92,460,379 and a literacy rate of 77.02%, sees THEFT as the most frequent crime, with a total of 1,119,304 reported cases.
#
# **Odisha:**
#
# Population: 42,471,303
# Literacy Rate: 73.85%
# Most Frequent Crime: THEFT
# Total Crimes: 647,946
# Odisha, with a population of 42.5 million and a literacy rate of 73.85%, experiences a notable occurrence of theft, making it the most prevalent crime in the state. The total number of reported crimes in Odisha is 647,946.
#
# **Assam:**
#
# Population: 31,622,339
# Literacy Rate: 73.08%
# Most Frequent Crime: THEFT
# Total Crimes: 597,764
# Assam, with a population of 31.6 million and a literacy rate of 73.08%, is marked by a significant incidence of theft, emerging as the most common crime. The total reported crimes in Assam amount to 597,764.
#
# **Haryana:**
#
# Population: 26,219,999
# Literacy Rate: 76.31%
# Most Frequent Crime: THEFT
# Total Crimes: 595,303
# Haryana, with a population of 26.2 million and a literacy rate of 76.31%, witnesses a substantial prevalence of theft, standing out as the most frequent crime. The state's total reported crimes reach 595,303.
#
# **Chhattisgarh:**
#
# Population: 26,010,762
# Literacy Rate: 70.84%
# Most Frequent Crime: HURT/GREVIOUS HURT
# Total Crimes: 561,027
# Chhattisgarh, with a population of 26 million and a literacy rate of 70.84%, experiences a high occurrence of hurt/grievous hurt as the most prevalent crime. The total reported crimes in Chhattisgarh amount to 561,027.
#
# **Jharkhand:**
#
# Population: 33,592,340
# Literacy Rate: 67.69%
# Most Frequent Crime: THEFT
# Total Crimes: 422,351
# Jharkhand, with a population of 33.6 million and a literacy rate of 67.69%, sees a notable incidence of theft as the most common crime. The total reported crimes in Jharkhand reach 422,351.
#
# **Punjab:**
#
# Population: 28,045,746
# Literacy Rate: 76.46%
# Most Frequent Crime: HURT/GREVIOUS HURT
# Total Crimes: 384,131
# Punjab, with a population of 28 million and a literacy rate of 76.46%, witnesses a significant occurrence of hurt/grievous hurt as the most frequent crime. The total reported crimes in Punjab amount to 384,131.
#
# **Jammu & Kashmir:**
#
# Population: 12,796,788
# Literacy Rate: 68.32%
# Most Frequent Crime: THEFT
# Total Crimes: 259,155
# Jammu & Kashmir, with a population of 12.8 million and a literacy rate of 68.32%, experiences a notable prevalence of theft as the most common crime. The total reported crimes in Jammu & Kashmir reach 259,155.
#
# **Himachal Pradesh:**
#
# Population: 6,934,414
# Literacy Rate: 83.43%
# Most Frequent Crime: HURT/GREVIOUS HURT
# Total Crimes: 154,948
# Himachal Pradesh, with a population of 6.9 million and a high literacy rate of 83.43%, sees a significant incidence of hurt/grievous hurt as the most frequent crime. The total reported crimes in Himachal Pradesh amount to 154,948.
#
# **Uttarakhand:**
#
# Population: 10,279,517
# Literacy Rate: 79.54%
# Most Frequent Crime: THEFT
# Total Crimes: 103,204
# Uttarakhand, with a population of 10.3 million and a literacy rate of 79.54%, experiences a notable occurrence of theft as the most prevalent crime. The total reported crimes in Uttarakhand reach 103,204.
#
# **Puducherry:**
#
# Population: 1,271,428
# Literacy Rate: 86.31%
# Most Frequent Crime: HURT/GREVIOUS HURT
# Total Crimes: 54,116
# Puducherry, with a population of 1.27 million and a high literacy rate of 86.31%, witnesses a significant incidence of hurt/grievous hurt as the most frequent crime. The total reported crimes in Puducherry amount to 54,116.
#
# **Tripura:**
#
# Population: 3,718,947
# Literacy Rate: 80.78%
# Most Frequent Crime: HURT/GREVIOUS HURT
# Total Crimes: 52,734
# Tripura, with a population of 3.7 million and a literacy rate of 80.78%, experiences a notable prevalence of hurt/grievous hurt as the most frequent crime. The total reported crimes in Tripura reach 52,734.
#
# **Chandigarh:**
#
# Population: 1,070,046
# Literacy Rate: 86.46%
# Most Frequent Crime: THEFT
# Total Crimes: 40,807
# Chandigarh, with a population of 1.07 million and a high literacy rate of 86.46%, sees a significant incidence of theft as the most common crime. The total reported crimes in Chandigarh amount to 40,807
#
# **Manipur:**
#
# Population: 2,764,483
# Literacy Rate: 77.58%
# Most Frequent Crime: THEFT
# Total Crimes: 35,072
# Manipur, with a population of 2,764,483, exhibits a relatively high literacy rate of 77.58%. The most frequently occurring crime in the state is 'THEFT,' with a total of 35,072 reported incidents.
#
# **Goa:**
#
# Population: 1,468,605
# Literacy Rate: 89.37%
# Most Frequent Crime: THEFT
# Total Crimes: 32,051
# Goa, with a population of 1,468,605, boasts a high literacy rate of 89.37%. 'THEFT' is the predominant crime in the state, with a total of 32,051 reported incidents.
#
# **Arunachal Pradesh:**
#
# Population: 1,411,039
# Literacy Rate: 66.48%
# Most Frequent Crime: THEFT
# Total Crimes: 27,652
# Arunachal Pradesh, with a population of 1,411,039, has a literacy rate of 66.48%. The most prevalent crime type in the state is 'THEFT,' with a total of 27,652 reported incidents.
#
# **Mizoram:**
#
# Population: 1,111,146
# Literacy Rate: 91.58%
# Most Frequent Crime: THEFT
# Total Crimes: 26,146
# Mizoram, home to 1,111,146 residents, boasts a high literacy rate of 91.58%. 'THEFT' is the most frequently reported crime, with a total of 26,146 incidents.
#
# **Meghalaya:**
#
# Population: 3,029,753
# Literacy Rate: 75.62%
# Most Frequent Crime: THEFT
# Total Crimes: 25,249
# Meghalaya, with a population of 3,029,753, has a literacy rate of 75.62%. The predominant crime type in the state is 'THEFT,' with a total of 25,249 reported incidents.
#
# **Nagaland:**
#
# Population: 1,979,634
# Literacy Rate: 80.85%
# Most Frequent Crime: THEFT
# Total Crimes: 13,133
# Nagaland, home to 1,979,634 residents, has a literacy rate of 80.85%. 'THEFT' is the most frequently reported crime, with a total of 13,133 incidents.
#
# **A & N Islands:**
#
# Population: 382,273
# Literacy Rate: 87.16%
# Most Frequent Crime: THEFT
# Total Crimes: 9,102
# The A & N Islands, with a population of 382,273, have an impressive literacy rate of 87.16%. 'THEFT' is the most frequently reported crime, with a total of 9,102 incidents.
#
# **Sikkim:**
#
# Population: 614,266
# Literacy Rate: 82.68%
# Most Frequent Crime: THEFT
# Total Crimes: 7,000
# Sikkim, with a population of 614,266, showcases a commendable literacy rate of 82.68%. 'THEFT' is the most frequently reported crime, with a total of 7,000 incidents.
#
# **D & N Haveli:**
#
# Population: 355,042
# Literacy Rate: 78.10%
# Most Frequent Crime: THEFT
# Total Crimes: 4,651
# D & N Haveli, with a population of 355,042, has a literacy rate of 78.10%. 'THEFT' is the most frequently reported crime, with a total of 4,651 incidents.
#
# **Daman & Diu:**
#
# Population: 251,394
# Literacy Rate: 87.99%
# Most Frequent Crime: THEFT
# Total Crimes: 2,948
# Daman & Diu, with a population of 251,394, boasts a high literacy rate of 87.99%. 'THEFT' is the most frequently reported crime, with a total of 2,948 incidents.
#
# **Lakshadweep:**
#
# Population: 64,741
# Literacy Rate: 92.37%
# Most Frequent Crime: RIOTS
# Total Crimes: 743
# Lakshadweep, with a population of 64,741, stands out with an exceptional literacy rate of 92.37%. Surprisingly, the most frequently reported crime in this union territory is 'RIOTS,' with a total of 743 incidents.
